# %% [markdown]
# <a href="https://colab.research.google.com/github/piblors/Introducao-a-ciencia-de-dados-e-IA-iesb-/blob/main/C%C3%B3pia_de_ListaExercicios_1_PythonExpress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá terráqueos")

# %%
# 2) Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]".

numero = input("Digite um número: ")
print(f"O número informado foi {numero}.")
# Out:
# Digite um número: 56
# O número informado foi 56.

# %%
# 3) Elabore um código que peça dois números e imprima a soma.

numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Digite o segundo número: "))
soma = numero1 + numero2
print(f"A soma dos números é: {soma}")
# Out:
# Digite o primeiro número: 3.6
# Digite o segundo número: 2.1
# A soma dos números é: 5.7

# %%
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
print(f"A média das notas é: {media}")
# Out:
# Digite a primeira nota: 5
# Digite a segunda nota: 8
# Digite a terceira nota: 3.8
# Digite a quarta nota: 1.2
# A média das notas é: 4.5

# %%
# 5) Elabore um código que converta metros para centímetros.

metros = float(input("Digite o valor em metros: "))
centimetros = metros * 100
print(f"{metros} metros equivalem a {centimetros} centímetros.")
# Out:
# Digite o valor em metros: 7
# 7.0 metros equivalem a 700.0 centímetros.

# %%
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.

raio = float(input("Digite o raio do círculo: "))
area = 3.14 * (raio ** 2)
print(f"A área do círculo é: {area:.2f}")
# Out:
# Digite o raio do círculo: 8
# A área do círculo é: 201.06

# %%
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

lado = float(input("Digite o lado do quadrado: "))
area_quadrado = lado ** 2
dobro_area = 2 * area_quadrado
print(f"A área do quadrado é: {area_quadrado}")
print(f"O dobro da área do quadrado é: {dobro_area}")
# Out:
# Digite o lado do quadrado: 9
# A área do quadrado é: 81.0
# O dobro da área do quadrado é: 162.0

# %%
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.

valor_hora = float(input("Quanto você ganha por hora? R$ "))
horas_mes = float(input("Quantas horas você trabalhou no mês? "))
salario_total = valor_hora * horas_mes
print(f"Olá! Seu salário total este mês é de R$ {salario_total:.2f}.")
# Out:
# Quanto você ganha por hora? R$ 45
# Quantas horas você trabalhou no mês? 80
# Olá! Seu salário total este mês é de R$ 3600.00.

# %%
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.

fahrenheit = float(input("Digite a temperatura em graus Fahrenheit: "))
celsius = 5 * ((fahrenheit - 32) / 9)
print(f"{fahrenheit}°F equivalem a {celsius:.2f}°C.")
# Out:
# Digite a temperatura em graus Fahrenheit: 234
# 234.0°F equivalem a 112.22°C.

# %%
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.

celsius = float(input("Digite a temperatura em graus Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C equivalem a {fahrenheit:.2f}°F.")
# Out:
# Digite a temperatura em graus Celsius: 78
# 78.0°C equivalem a 172.40°F.

# %%
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.

num_int1 = int(input("Digite o primeiro número inteiro: "))
num_int2 = int(input("Digite o segundo número inteiro: "))
num_real = float(input("Digite um número real: "))

# Produto do dobro do primeiro com metade do segundo
resultado1 = (2 * num_int1) * (num_int2 / 2)
print(f"O produto do dobro do primeiro com metade do segundo é: {resultado1}")

# Soma do triplo do primeiro com o terceiro
resultado2 = (3 * num_int1) + num_real
print(f"A soma do triplo do primeiro com o terceiro é: {resultado2}")

# Terceiro elevado ao cubo
resultado3 = num_real ** 3
print(f"O terceiro elevado ao cubo é: {resultado3}")
# Out:
# Digite o primeiro número inteiro: 5
# Digite o segundo número inteiro: 87
# Digite um número real: 3.5
# O produto do dobro do primeiro com metade do segundo é: 435.0
# A soma do triplo do primeiro com o terceiro é: 18.5
# O terceiro elevado ao cubo é: 42.875

# %%
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

altura = float(input("Digite sua altura em metros: "))
peso_ideal = (72.7 * altura) - 58
print(f"Para uma altura de {altura}m, o peso ideal seria: {peso_ideal:.2f} kg.")
# Out:
# Digite sua altura em metros: 1.81
# Para uma altura de 1.81m, o peso ideal seria: 73.59 kg.
